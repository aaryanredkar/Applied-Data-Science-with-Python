# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df1  = pd.read_csv("/Users/aaryanredkar/Applied Data Science with Python/Course 2 Applied Plotting, Charting & Data Representation in Python /Week 4/datatrial.csv")
df1.head(48)
# Out:
#        date  android  apple  microsoft  blackberry
# 0   Jan '12     48.6   29.5        4.4        15.2
# 1   Feb '12     50.1   30.2        3.9        13.4
# 2   Mar '12     51.0   30.7        3.9        12.3
# 3   Apr '12     50.8   31.4        4.0        11.6
# 4   May '12     50.9   31.9        4.0        11.4
# 5   Jun '12     51.6   32.4        3.8        10.7
# 6   Jul '12     52.2   33.4        3.6         9.5
# 7   Aug '12     52.6   34.3        3.6         8.3
# 8   Sep '12     52.5   34.3        3.6         8.4
# 9   Oct '12     53.6   34.3        3.2         7.8
# 10  Nov '12     53.7   35.0        3.0         7.3
# 11  Dec '12     53.4   36.3        2.9         6.4
# 12  Jan '13     52.3   37.8        3.1         5.9
# 13  Feb '13     51.7   38.9        3.2         5.4
# 14  Mar '13     52.0   39.0        3.0         5.2
# 15  Apr '13     52.0   39.2        3.0         5.1
# 16  May '13     52.4   39.2        3.0         4.8
# ...

# %%
df1.plot(kind='line',x='date', figsize = (18,8), marker = 'o')
plt.ylabel('Percent (%)')
plt.xlabel('Date')
plt.title('Mobile OS Market share In United States')
# Out:
# Text(0.5, 1.0, 'Mobile OS Market share In United States')

# %%
df1.plot(kind='bar',x='date', figsize = (40,28))
plt.ylabel('Percent (%)')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
df1.plot(kind='scatter',x='date',y='android', figsize = (50,15))

# %%
df1.plot(kind='scatter',x='date',y='apple', figsize = (50,15))

# %%
df1.plot(kind='scatter',x='date',y='microsoft', figsize = (50,15))

# %%
df1.plot(kind='scatter',x='date',y='blackberry', figsize = (50,15))
