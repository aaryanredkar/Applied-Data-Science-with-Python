# %%
import pandas as pd
import matplotlib.pyplot as plt
df1  = pd.read_csv("/Users/aaryanredkar/Applied Data Science with Python/Course 2 Applied Plotting, Charting & Data Representation in Python /Week 4/android.csv")
df1.head()


 # scatter plot
#df.plot(kind='density')  # estimate density function
# df.plot(kind='hist')  # histogram
# Out:
#       date  percent
# 0  Jan '12     48.6
# 1  Feb '12     50.1
# 2  Mar '12     51.0
# 3  Apr '12     50.8
# 4  May '12     50.9

# %%
df2  = pd.read_csv("/Users/aaryanredkar/Applied Data Science with Python/Course 2 Applied Plotting, Charting & Data Representation in Python /Week 4/apple.csv")
df2.head()
# Out:
#        date  percent
# 0   Jan '12     29.5
# 1   Feb '12     30.2
# 2  Mar  '12     30.7
# 3   Apr '12     31.4
# 4  May  '12     31.9

# %%
df1.plot()

# %%
df1.plot(kind='scatter',x='date',y='percent', figsize = (50,15))
df2.plot(kind='scatter',x='date',y='percent', figsize = (50,15))
